# %%
import numpy as np
import pandas as pd

import torch 
import torchaudio
import torchaudio.transforms as AT

import matplotlib.pyplot as plt

from librosa.filters import mel as librosa_mel

from vocex import Vocex

# %%
# !curl -L https://free.keep.sh/XhdwMjSeqVr4lyCz/test.wav > test.wav

# %%
audio_args = {
    "n_fft": 1024,  
    "win_length": 1024,  
    "hop_length": 256, 
    "n_mels": 80,
}

sampling_rate=22050

# Let's load some SWB audio
# AUDIO_ROOT='/disk/scratch/swallbridge/switchboard_separated'
# audio_file = 'sw02835_B.wav'
# audio_fp = f"{AUDIO_ROOT}/{audio_file}"

# Let's load some libritts data
audio_fp = 'test.wav'

# %%
audio_raw, sr = torchaudio.load(audio_fp)


audio_resampled = audio_raw
if sr != sampling_rate:
    audio_resampled = torchaudio.transforms.Resample(sr, sampling_rate)(audio_raw)

audio = audio_resampled / np.abs(audio_resampled).max()

# %%
audio
# Out:
# tensor([[-0.0007, -0.0004, -0.0002,  ..., -0.0020, -0.0019, -0.0016]])

# %%
mel_spectrogram = AT.Spectrogram(
    n_fft=audio_args["n_fft"],
    win_length=audio_args["win_length"],
    hop_length=audio_args["hop_length"],
    pad=0,
    window_fn=torch.hann_window,
    power=2.0,
    normalized=False,
    center=True,
    pad_mode="reflect",
    onesided=True,
)

mel_basis = librosa_mel(
    sr=sampling_rate,
    n_fft=audio_args["n_fft"],
    n_mels=audio_args["n_mels"],
    fmin=0,
    fmax=8000,
)

mel_basis = torch.from_numpy(mel_basis).float()

# %%
def drc(x, C=1, clip_val=1e-7):
        return torch.log(torch.clamp(x, min=clip_val) * C)

# %%
# mel = mel_spectrogram(torch.tensor(batch[i]["audio"]).unsqueeze(0))
mel = mel_spectrogram(audio)
mel = torch.sqrt(mel[0])
mel = torch.matmul(mel_basis, mel)
mel = drc(mel)

# %%
mel_plt = mel[:,:1000]

# %%
# import matplotlib.pyplot as plt
display(mel_plt.shape)
display(mel_plt.max())
display(mel_plt.min())
# Out:
# torch.Size([80, 242])
# tensor(1.2273)
# tensor(-10.2357)

# %%
# Plot the spectrogram
fig, axes = plt.subplots(1,1,figsize=(16,10))
axes.imshow(mel_plt, origin='lower')

# %%
import IPython.display as ipd

# %%
audio_plt = audio[:,:sampling_rate*10]
ipd.Audio(audio_plt, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# torch.load('models/vocex_libritts_100k.pt', map_location=torch.device("cpu"))

# %%
model = Vocex()
model.load_state_dict(
    torch.load("models/vocex_libritts_100k_cpu.pt", map_location=torch.device("cpu")),
                     )
# Out:
# <All keys matched successfully>

# %%
mel_pad = torch.concat((mel, torch.zeros((80, 14))), dim=1)
mel_pad = mel_pad.T.unsqueeze(0)
mel_pad.shape
# Out:
# torch.Size([1, 256, 80])

# %%
features = model(mel_pad, inference=True,)
# Out:
# tensor(-2.4985) tensor(2.5000)

# %%
features['measures']['energy'].min(), features['measures']['energy'].max()
# Out:
# (tensor(-2.3323, grad_fn=<MinBackward1>),
#  tensor(2.3992, grad_fn=<MaxBackward1>))

# %%
# Plot the spectrogram
fig, axes = plt.subplots(3,1,figsize=(16,10))
ax = axes[0]
ax.imshow(mel_pad[0].T, origin='lower')

y = features['measures']['energy'].flatten(0).detach().numpy()
x = range(len(y))
ax = axes[1]
ax.plot(x,y)
ax.set_title('energy')

y = features['measures']['pitch'].flatten(0).detach().numpy()
x = range(len(y))
ax = axes[2]
ax.plot(x,y)
ax.set_title('pitch')
# Out:
# Text(0.5, 1.0, 'pitch')

# %%
features['measures']['pitch']
# Out:
# tensor([[-1.9739, -1.6839, -1.5967, -1.5401, -1.2191, -0.5339, -0.2871, -0.1005,
#          -0.0581, -0.0871, -0.0918, -0.1868, -0.1212, -0.1154, -0.0581, -0.0367,
#          -0.0880, -0.4104, -0.5191, -0.7475, -0.7047, -0.8166, -0.8243, -0.7538,
#          -0.6135, -0.3134, -0.1643, -0.1291, -0.0847, -0.0763, -0.1496, -0.3583,
#          -0.3487, -0.5470, -0.8239, -0.9702, -0.8275, -0.5101, -0.4822, -0.7450,
#          -0.6437, -0.7647, -0.6601, -0.3207, -0.4031, -0.2304, -0.2669, -0.1538,
#          -0.2168, -0.1945, -0.4798, -0.9029, -0.8108, -0.7961, -1.2014, -1.1404,
#          -1.0663, -0.8911, -0.6661, -0.5264, -0.3651, -0.2870, -0.3729, -0.5666,
#          -0.6851, -0.4243, -0.7148, -0.6407, -0.6794, -0.7833, -0.7706, -0.6999,
#          -0.7921, -0.5269, -0.1689, -0.2038, -0.1743, -0.0754, -0.0569, -0.1447,
#          -0.1938, -0.1870, -0.1114, -0.3731, -0.3644, -0.2948, -0.4316, -0.6931,
#          -0.7833, -0.7219, -0.9004, -1.1199, -1.2428, -1.1620, -0.9797, -0.6249,
#          -0.4759, -0.3584, -0.4592, -0.3700, -0.2727, -0.1683, -0.2404, -0.2593,
#          -0.1171, -0.1621, -0.1685, -0.4518, -0.4158, -0.3127, -0.5171, -0.6838,
#          -0.6093, -0.4285, -0.4514, -0.5198, -0.1989, -0.0547, -0.2958, -0.5224,
#          -0.8409, -0.9845, -1.1375, -1.5716, -1.3381, -1.5495, -1.1041, -0.7372,
#          -0.8058, -1.4752, -1.4542, -1.2954, -1.0729, -0.4964, -0.2770, -0.2379,
#          -0.2197, -0.1464, -0.2479, -0.2947, -0.1378, -0.1512, -0.1738, -0.1510,
#          -0.2279, -0.1462, -0.2369, -0.2482, -0.2898, -0.2254, -0.2177, -0.2532,
#          -0.2172, -0.2511, -0.3423, -0.4557, -0.4325, -0.3872, -0.3739, -0.5781,
#          -0.8674, -0.8360, -1.0054, -1.0596, -1.1536, -0.6951, -0.7453, -0.5935,
#          -0.3978, -0.4339, -0.6292, -0.4575, -0.2678, -0.2289, -0.3388, -0.2738,
#          -0.2241, -0.3342, -0.3508, -0.2510, -0.3326, -0.4816, -0.3852, -0.3003,
#          -0.2594, -0.2008, -0.2203, -0.3742, -0.3478, -0.4007, -0.3969, -0.3603,
#          -0.2971, -0.4370, -0.5940, -0.6390, -0.7105, -0.6344, -0.5478, -0.3724,
#          -0.3235, -0.2935, -0.3106, -0.4234, -0.2977, -0.3032, -0.2939, -0.4849,
#          -0.4139, -0.3650, -0.5951, -0.6814, -0.4826, -0.4138, -0.4124, -0.4610,
#          -0.6283, -0.6198, -0.7837, -0.9556, -0.6102, -0.5615, -0.5189, -0.4635,
#          -0.4231, -0.3547, -0.6241, -0.5479, -0.4761, -0.5025, -0.7136, -0.7971,
#          -0.5617, -0.4218, -0.4603, -0.4236, -0.3416, -0.3916, -0.4179, -0.6036,
#          -0.6790, -1.4649, -1.6705, -1.7041, -1.9854, -1.6510, -1.5641, -1.2789,
#          -1.5075, -1.3824, -1.5115, -1.4564, -1.4847, -1.6039, -1.8900, -1.2605]],
#        grad_fn=<SelectBackward0>)

# %%
import pyworld as pw
_f0, t = pw.dio(audio_plt.flatten(0).numpy().astype(np.float64), sampling_rate)    # raw pitch extractor
f0 = pw.stonemask(audio_plt.flatten(0).numpy().astype(np.float64), _f0, t, sampling_rate)  # pitch refinement

# %%
# Plot the spectrogram
fig, axes = plt.subplots(2,1,figsize=(16,10))
# ax = axes[0]
# ax.imshow(mel[:,400:656], origin='lower')

y = f0
x = range(len(y))
ax = axes[0]
ax.plot(x,y)
ax.set_title('PyWorld')

y = features['measures']['pitch'].flatten(0).detach().numpy()
x = range(len(y))
ax = axes[1]
ax.plot(x,y)
ax.set_title('Vocex')
# Out:
# Text(0.5, 1.0, 'Vocex')
